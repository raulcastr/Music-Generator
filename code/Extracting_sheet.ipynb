# %%
import music21

# %%
original_score = music21.converter.parse("../data/generated_songs/chsmas_decent.mid").chordify()

# %%
env = music21.environment.Environment()

# set path if necessary
env['musicxmlPath'] = r'C:\Program Files\MuseScore 3\bin\MuseScore3.exe'
env['musescoreDirectPNGPath'] = r'C:\Program Files\MuseScore 3\bin\MuseScore3.exe'

# %%
original_score.show()
